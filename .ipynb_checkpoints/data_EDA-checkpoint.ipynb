# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"waitlist_kidney_brazil.csv")

# %%
df.head()
# Out:
#    Id       date  age_at_list_registration   age_cat  time_on_Dialysis  \
# 0   4  6/29/2017                        67  Maior.60               1.0
# 1   5  11/3/2008                        58   18.a.60               4.0
# 2   6  7/13/2010                        51   18.a.60               2.0
# 3   7  10/3/2011                        52   18.a.60              17.0
# 4   8   7/5/2006                        67  Maior.60              68.0
#
#      race sex underline_disease  diabetes Blood_type  ...  Time_death  \
# 0  Branca   M            Outras         1          A  ...          13
# 1  Branca   M          Diabetes         0          A  ...          69
# 2  Branca   M               HAS         1          O  ...          98
# 3  Branca   M          Diabetes         0          O  ...          83
# 4   Parda   M               HAS         1          A  ...           6
#
#     Transplant  Transplant_Y_N X36MthsTx  Time_Tx priorization  removed_list  \
# 0          Não             Não         0    13.07          Não           Não
# 1  Óbito Lista             Não         0    68.87          Não           Não
# 2          Não             Não         0    12.17          Não           Sim
# 3          Não             Não         0    12.17          Não           Sim
# 4  Óbito Lista             Não         0     6.47          Não           Não
#
#                     razon_removed  time  event
# 0                             NaN   392      0
# 1                             NaN  2066      2
# 2  Removido (suspenso > 365 dias)   365      3
# 3  Removido (suspenso > 365 dias)   365      3
# 4                             NaN   194      2
#
# [5 rows x 53 columns]

# %%
# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Calculate the number of rows and columns for subplots
num_plots = len(categorical_columns)
num_rows = (num_plots // 2) + (num_plots % 2)
num_cols = 2

fig, axes = plt.subplots(num_rows,num_cols, figsize = (20,35))

# Distance between graphs
plt.subplots_adjust(hspace=0.5)

categorical_columns
# Build countplots for each feature
for i, column in enumerate(categorical_columns):
    if column != "date":
        ax = axes[i // 2, i % 2]
        sns.countplot(data=df, x=column, ax=ax)
        
        ax.set_title(column, fontweight = 'bold', fontsize = 16)
        ax.set_xlabel("")
        ax.set_ylabel('Count', fontsize = 14)
        ax.tick_params( rotation=20)

plt.show()

# %%
categorical_columns
# Out:
# Index(['date', 'age_cat', 'race', 'sex', 'underline_disease', 'Blood_type',
#        'gestation', 'prior_transplant', 'subregion', 'cPRA_cat', 'DR_00',
#        'B_00', 'A_00', 'chagas', 'anti.HBc', 'anti.HCV', 'agHBs',
#        'patient_still_on_list', 'death', 'Transplant', 'Transplant_Y_N',
#        'priorization', 'removed_list', 'razon_removed'],
#       dtype='object')

# %%
df["razon_removed"].unique()
# Out:
# array([nan, 'Removido (suspenso > 365 dias)',
#        'Não quer ser transplantado', 'Transferido para outro Estado',
#        'Removido sem condições clínicas', 'Abandonou o tratamento',
#        'Removido pela equipe', 'Removido administrativo',
#        'Função renal recuperada', 'Removido (inscrição duplicada)',
#        'Transferido de Equipe'], dtype=object)

# %%
sns.boxplot(df, x="number_gestation")
# Out:
# <Axes: xlabel='number_gestation'>

# %% [markdown]
# # Pre Processing

# %%
from cleanProcess.DataCleaning import GetData
pathcsv = "waitlist_kidney_brazil.csv"
Data = GetData(path=pathcsv)

# %%
Data.raw_data.head(5)
# Out:
#    Id       date  age_at_list_registration   age_cat  time_on_Dialysis  \
# 0   4  6/29/2017                        67  Maior.60               1.0
# 1   5  11/3/2008                        58   18.a.60               4.0
# 2   6  7/13/2010                        51   18.a.60               2.0
# 3   7  10/3/2011                        52   18.a.60              17.0
# 4   8   7/5/2006                        67  Maior.60              68.0
#
#      race sex underline_disease  diabetes Blood_type  ...  Time_death  \
# 0  Branca   M            Outras         1          A  ...          13
# 1  Branca   M          Diabetes         0          A  ...          69
# 2  Branca   M               HAS         1          O  ...          98
# 3  Branca   M          Diabetes         0          O  ...          83
# 4   Parda   M               HAS         1          A  ...           6
#
#     Transplant  Transplant_Y_N X36MthsTx  Time_Tx priorization  removed_list  \
# 0          Não             Não         0    13.07          Não           Não
# 1  Óbito Lista             Não         0    68.87          Não           Não
# 2          Não             Não         0    12.17          Não           Sim
# 3          Não             Não         0    12.17          Não           Sim
# 4  Óbito Lista             Não         0     6.47          Não           Não
#
#                     razon_removed  time  event
# 0                             NaN   392      0
# 1                             NaN  2066      2
# 2  Removido (suspenso > 365 dias)   365      3
# 3  Removido (suspenso > 365 dias)   365      3
# 4                             NaN   194      2
#
# [5 rows x 53 columns]

# %%
Data.cleaned_data.head(5)
# Out:
#     age_at_list_registration  time_on_Dialysis   race sex underline_disease  \
# 28                        33              12.0  Brown   F               GNC
# 34                        66              20.0  White   F            Others
# 38                        58               3.0  White   F          Diabetes
# 44                        39               3.0  White   F            Others
# 46                        56               5.0  Black   F          Diabetes
#
#     diabetes Blood_type  number_transfusion  gestation  number_gestation  ...  \
# 28         1          A                   0      False               0.0  ...
# 34         1         AB                   1       True               3.0  ...
# 38         0          A                   0      False               0.0  ...
# 44         1          A                   2       True               3.0  ...
# 46         0          O                   0       True               3.0  ...
#
#     HLA_DR2         DR_00          B_00          A_00  chagas  anti.HBc  \
# 28       15  heterozygous  heterozygous  heterozygous   False     False
# 34       11  heterozygous  heterozygous  heterozygous   False     False
# 38       13  heterozygous  heterozygous  heterozygous   False     False
# 44       14  heterozygous  heterozygous    homozygous   False     False
# 46       13  heterozygous  heterozygous  heterozygous   False     False
#
#     anti.HCV  agHBs  time  event
# 28     False  False   464      1
# 34     False  False  1708      1
# 38     False  False   288      1
# 44     False  False  6342      0
# 46     False  False   423      0
#
# [5 rows x 29 columns]

# %%
Xtrain, Ytrain, Xtest, Ytest = Data.get_splitted_scale_encoded_data()

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_clean = Data.cleaned_data
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9257 entries, 28 to 48151
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age_at_list_registration  9257 non-null   int64
#  1   time_on_Dialysis          9257 non-null   float64
#  2   race                      9257 non-null   object
#  3   sex                       9257 non-null   int32
#  4   underline_disease         9257 non-null   object
#  5   diabetes                  9257 non-null   int64
#  6   Blood_type                9257 non-null   object
#  7   number_transfusion        9257 non-null   int64
#  8   gestation                 9257 non-null   int64
#  9   number_gestation          9257 non-null   float64
#  10  prior_transplant          9257 non-null   int64
#  11  number_prior_transplant   9257 non-null   int64
#  12  subregion                 9257 non-null   object
#  13  cPRA                      9257 non-null   int64
#  14  HLA_A1                    9257 non-null   int64
#  15  HLA_A2                    9257 non-null   int64
#  16  HLA_B1                    9257 non-null   int64
#  17  HLA_B2                    9257 non-null   int64
#  18  HLA_DR1                   9257 non-null   int64
#  19  HLA_DR2                   9257 non-null   int64
#  20  DR_00                     9257 non-null   int32
#  21  B_00                      9257 non-null   int32
#  22  A_00                      9257 non-null   int32
#  23  chagas                    9257 non-null   int32
#  24  anti.HBc                  9257 non-null   int64
#  25  anti.HCV                  9257 non-null   int32
#  26  agHBs                     9257 non-null   int32
#  27  time                      9257 non-null   int64
#  28  event                     9257 non-null   int64
# dtypes: float64(2), int32(7), int64(16), object(4)
# memory usage: 1.9+ MB

# %%
df_clean.describe()
# Out:
#        age_at_list_registration  time_on_Dialysis          sex     diabetes  \
# count               9257.000000       9257.000000  9257.000000  9257.000000
# mean                  44.406395         22.328832     0.000216     0.872745
# std                   14.375517         30.731079     0.014698     0.333276
# min                    0.000000          0.000000     0.000000     0.000000
# 25%                   35.000000          6.000000     0.000000     1.000000
# 50%                   45.000000         11.000000     0.000000     1.000000
# 75%                   55.000000         25.000000     0.000000     1.000000
# max                   87.000000        180.000000     1.000000     1.000000
#
#        number_transfusion    gestation  number_gestation  prior_transplant  \
# count         9257.000000  9257.000000       9257.000000       9257.000000
# mean             0.535055     0.657772          1.992438          0.146808
# std              0.703805     0.474481          2.098881          0.353933
# min              0.000000     0.000000          0.000000          0.000000
# 25%              0.000000     0.000000          0.000000          0.000000
# 50%              0.000000     1.000000          2.000000          0.000000
# 75%              1.000000     1.000000          3.000000          0.000000
# max              3.000000     1.000000         15.000000          1.000000
#
#        number_prior_transplant         cPRA  ...      HLA_DR2        DR_00  \
# count              9257.000000  9257.000000  ...  9257.000000  9257.000000
# mean                  0.167873    25.036081  ...    10.480285     0.080156
# std                   0.435950    35.555093  ...     4.707919     0.271549
# min                   0.000000     0.000000  ...     0.000000     0.000000
# 25%                   0.000000     0.000000  ...     7.000000     0.000000
# 50%                   0.000000     0.000000  ...    12.000000     0.000000
# 75%                   0.000000    52.000000  ...    14.000000     0.000000
# max                   5.000000   100.000000  ...    16.000000     1.000000
#
#               B_00         A_00       chagas     anti.HBc     anti.HCV  \
# count  9257.000000  9257.000000  9257.000000  9257.000000  9257.000000
# mean      0.054985     0.091498     0.001944     0.020525     0.008858
# std       0.227964     0.288332     0.044056     0.141795     0.093705
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              agHBs         time        event
# count  9257.000000  9257.000000  9257.000000
# mean      0.002485  1097.110403     0.512585
# std       0.049787  1024.420685     0.499869
# min       0.000000     3.000000     0.000000
# 25%       0.000000   380.000000     0.000000
# 50%       0.000000   766.000000     1.000000
# 75%       0.000000  1471.000000     1.000000
# max       1.000000  6713.000000     1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ### Numeric Variables

# %%
# Identify numeric columns
# numeric_columns = df_clean.select_dtypes(include=['int','float']).columns
# numeric_columns
# Out:
# Index(['age_at_list_registration', 'time_on_Dialysis', 'sex', 'diabetes',
#        'number_transfusion', 'gestation', 'number_gestation',
#        'prior_transplant', 'number_prior_transplant', 'cPRA', 'HLA_A1',
#        'HLA_A2', 'HLA_B1', 'HLA_B2', 'HLA_DR1', 'HLA_DR2', 'DR_00', 'B_00',
#        'A_00', 'chagas', 'anti.HBc', 'anti.HCV', 'agHBs', 'time', 'event'],
#       dtype='object')

# %%
numeric_columns = ['age_at_list_registration', 
                     'time_on_Dialysis',
                     'number_transfusion',
                     'number_gestation',
                     'number_prior_transplant',
                     'cPRA', 
                     'HLA_A1', 'HLA_A2', 'HLA_B1', 'HLA_B2', 'HLA_DR1', 'HLA_DR2',
                     'time']

# %%
# Calculate the number of rows and columns for subplots
num_plots_n = len(numeric_columns)
num_rows_n = (num_plots_n // 2) + (num_plots_n % 2)
num_cols_n = 2

fig, axes = plt.subplots(num_rows_n, num_cols_n, figsize = (30,30))

# Distance between graphs
plt.subplots_adjust(hspace=0.5)

# Build distributions for each feature
for i, column in enumerate(numeric_columns):
    ax = axes[i // 2, i % 2]
    sns.histplot(df_clean[column], kde=True, ax=ax)
    ax.set_title(column, fontweight = 'bold', fontsize = 16)
    ax.set_xlabel("")
    ax.set_ylabel('Count', fontsize = 14)
    ax.tick_params(rotation=20)

plt.show()

# %% [markdown]
# From a initial view of the numeric variable distributions, we can see that the following variables have a very long tail, with the majority of patients falling in the lower range.
# *  Time on Dialysis (months)
# *  cPRA
# *  Number of Gestations (i.e., pregnancies)
# *  Time on waitlist (months)

# %%
# Create a pairplot to visualize relationships between features
g = sns.PairGrid(df_clean, y_vars=["time"], x_vars=["time_on_Dialysis", "cPRA", "number_gestation"], height=4)
g.map(sns.scatterplot)

# %%
g = sns.FacetGrid(df_clean, col="sex", margin_titles=True, height=4)
g.map(plt.scatter, "number_gestation", "time", edgecolor="white", s=50, lw=1)

# %%
g = sns.FacetGrid(df_clean, col="subregion", row="race", hue="subregion", margin_titles=True, height=4)
g.map(plt.scatter, "number_gestation", "time", edgecolor="white", s=50, lw=1)

# %%
variables = ['age_at_list_registration', 'time_on_Dialysis', 'number_gestation', 'cPRA', 'time']
g = sns.PairGrid(df_clean, hue="cPRA", vars=variables)
g.map_diag(sns.histplot, hue=None, color=".3")
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
sns.boxplot(df_clean, x="number_gestation")
# Out:
# <Axes: xlabel='number_gestation'>

# %%
# log transform time on dialysis
# df_clean["time_on_Dialysis_log"] = np.log10(df_clean['time_on_Dialysis'], where=(df_clean['time_on_Dialysis']!=0))

# %%
# df_clean["time_on_Dialysis_log"].describe()
# Out:
# count    9257.000000
# mean        1.086873
# std         0.501102
# min         0.000000
# 25%         0.778151
# 50%         1.041393
# 75%         1.397940
# max         5.192957
# Name: time_on_Dialysis_log, dtype: float64

# %%
# Create a pairplot to visualize relationships between features
# g = sns.PairGrid(df_clean, y_vars=["time"], x_vars=["time_on_Dialysis", "time_on_Dialysis_log"], height=4)
# g.map(sns.scatterplot)

# %% [markdown]
# ### Categorical Variables

# %%
# Identify categorical columns
# categorical_columns = df_clean.select_dtypes(include=['int']).columns
# categorical_columns
# Out:
# Index(['age_at_list_registration', 'sex', 'diabetes', 'number_transfusion',
#        'gestation', 'prior_transplant', 'number_prior_transplant', 'cPRA',
#        'HLA_A1', 'HLA_A2', 'HLA_B1', 'HLA_B2', 'HLA_DR1', 'HLA_DR2', 'DR_00',
#        'B_00', 'A_00', 'chagas', 'anti.HBc', 'anti.HCV', 'agHBs', 'time',
#        'event'],
#       dtype='object')

# %%
categorical_columns = ['sex', 
                       'diabetes', 
                       'gestation', 
                       'prior_transplant',
                       'chagas', 
                       'anti.HBc', 
                       'anti.HCV', 
                       'agHBs',
                       'event']

# %%
# Calculate the number of rows and columns for subplots
num_plots_c = len(categorical_columns)
num_rows_c = (num_plots_c // 2) + (num_plots_c % 2)
num_cols_c = 2

fig, axes = plt.subplots(num_rows_c, num_cols_c, figsize = (35,30))

# Distance between graphs
plt.subplots_adjust(hspace=0.5)

# Build distributions for each feature, normalized to show percentage
for i, column in enumerate(categorical_columns):
    ax = axes[i // 2, i % 2]
    sns.countplot(data=df_clean, x=column, ax=ax)
    ax.set_title(column, fontweight = 'bold', fontsize = 16)
    ax.set_xlabel("")
    ax.set_ylabel('Count', fontsize = 14)
    ax.tick_params(rotation=20)

plt.show()

# %% [markdown]
# ### Correlations

# %%
# get correlations
sns.heatmap(df_clean.corr(numeric_only=True),cmap='viridis')
# Out:
# <Axes: >

# %%
df_clean.corr(numeric_only=True)['time'][:-1].sort_values()
# Out:
# HLA_DR2                    -0.057252
# time_on_Dialysis           -0.055147
# number_transfusion         -0.047843
# anti.HBc                   -0.025457
# age_at_list_registration   -0.024245
# chagas                     -0.019412
# HLA_B2                     -0.019010
# gestation                  -0.012541
# number_gestation           -0.006503
# number_prior_transplant    -0.003297
# sex                        -0.002255
# agHBs                       0.000624
# prior_transplant            0.004049
# HLA_A2                      0.004083
# HLA_DR1                     0.019168
# anti.HCV                    0.021686
# HLA_B1                      0.023983
# HLA_A1                      0.045174
# A_00                        0.054478
# B_00                        0.075028
# diabetes                    0.113272
# DR_00                       0.150811
# cPRA                        0.155196
# time                        1.000000
# Name: time, dtype: float64
